# %% [markdown]
# ### 7.1 Symmetric Cusum Filter on Revenue

# %%
# In pypm.filters
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
def calculate_non_uniform_lagged_change(series: pd.Series, n_days: int):
    """
    Use pd.Series.searchsorted to measure the lagged change in a non-uniformly 
    spaced time series over n_days of calendar time. 
    """

    # Get mapping from now to n_days ago at every point
    _timedelta: pd.Timedelta = pd.Timedelta(days=n_days)
    _idx: pd.Series = series.index.searchsorted(series.index - _timedelta)
    _idx = _idx[_idx > 0]

    # Get the last len(series) - n_days values
    _series = series.iloc[-_idx.shape[0]:]

    # Build a padding of NA values
    _pad_length = series.shape[0] - _idx.shape[0]
    _na_pad = pd.Series(None, index=series.index[:_pad_length])

    # Get the corresonding lagged values
    _lagged_series = series.iloc[_idx]

    # Measure the difference
    _diff = pd.Series(_series.values-_lagged_series.values, index=_series.index)

    return pd.concat([_na_pad, _diff])

# %%
def calculate_cusum_events(series: pd.Series, 
    filter_threshold: float) -> pd.DatetimeIndex:
    """
    Calculate symmetric cusum filter and corresponding events
    """

    event_dates = list()
    s_up = 0
    s_down = 0

    for date, price in series.items():
        s_up = max(0, s_up + price)
        s_down = min(0, s_down + price)

        if s_up > filter_threshold:
            s_up = 0
            event_dates.append(date)

        elif s_down < -filter_threshold:
            s_down = 0
            event_dates.append(date)

    return pd.DatetimeIndex(event_dates)

# %%
# load path
import sys
if "src/" not in sys.path:
    sys.path.append("src/")

# In pypm.ml_model.events
from pypm import filters

# %%
def calculate_events_for_revenue_series(series: pd.Series, 
    filter_threshold: float, lookback: int=365) -> pd.DatetimeIndex:
    """
    Calculate the symmetric cusum filter to generate events on YoY changes in 
    the log revenue series
    """
    series = np.log(series)
    series = filters.calculate_non_uniform_lagged_change(series, lookback)
    return filters.calculate_cusum_events(series, filter_threshold)

# %%
def calculate_events(revenue_series: pd.Series):
    return calculate_events_for_revenue_series(
        revenue_series,
        filter_threshold=5,
        lookback=365,
    )

# %% [markdown]
# ### 7.2 Computing Triple Barrier Labels

# %%
# See pypm.labels
import numpy as np
import pandas as pd
from typing import Tuple

# %%
def compute_triple_barrier_labels(
    price_series: pd.Series, 
    event_index: pd.Series, 
    time_delta_days: int, 
    upper_delta: float=None, 
    lower_delta: float=None, 
    vol_span: int=20, 
    upper_z: float=None,
    lower_z: float=None,
    upper_label: int=1, 
    lower_label: int=-1) -> Tuple[pd.Series, pd.Series]:
    """
    Calculate event labels according to the triple-barrier method. 

    Return a series with both the original events and the labels. Labels 1, 0, 
    and -1 correspond to upper barrier breach, vertical barrier breach, and 
    lower barrier breach, respectively. 

    Also return series where the index is the start date of the label and the 
    values are the end dates of the label.
    """

    timedelta = pd.Timedelta(days=time_delta_days)
    series = pd.Series(np.log(price_series.values), index=price_series.index)

    # A list with elements of {-1, 0, 1} indicating the outcome of the events
    labels = list()
    label_dates = list()

    if upper_z or lower_z:
        volatility = series.ewm(span=vol_span).std()
        volatility *= np.sqrt(time_delta_days / vol_span)

    for event_date in event_index:
        date_barrier = event_date + timedelta

        start_price = series.loc[event_date]
        log_returns = series.loc[event_date:date_barrier] - start_price

        # First element of tuple is 1 or -1 indicating upper or lower barrier
        # Second element of tuple is first date when barrier was crossed
        candidates: List[Tuple[int, pd.Timestamp]] = list()

        # Add the first upper or lower delta crosses to candidates
        if upper_delta:
            _date = log_returns[log_returns > upper_delta].first_valid_index()
            if _date:
                candidates.append((upper_label, _date))
    
        if lower_delta:
            _date = log_returns[log_returns < lower_delta].first_valid_index()
            if _date:
                candidates.append((lower_label, _date))

        # Add the first upper_z and lower_z crosses to candidates
        if upper_z:
            upper_barrier = upper_z * volatility[event_date]
            _date = log_returns[log_returns > upper_barrier].first_valid_index()
            if _date:
                candidates.append((upper_label, _date))

        if lower_z:
            lower_barrier = lower_z * volatility[event_date]
            _date = log_returns[log_returns < lower_barrier].first_valid_index()
            if _date:
                candidates.append((lower_label, _date))

        if candidates:
            # If any candidates, return label for first date
            label, label_date = min(candidates, key=lambda x: x[1])
        else:
            # If there were no candidates, time barrier was touched
            label, label_date = 0, date_barrier

        labels.append(label)
        label_dates.append(label_date)

    label_series = pd.Series(labels, index=event_index)
    event_spans = pd.Series(label_dates, index=event_index)

    return label_series, event_spans

# %%
# See pypm.ml_model.labels
from typing import Tuple
from pypm import labels

# %%
def calculate_labels(price_series, event_index) -> Tuple[pd.Series, pd.Series]:
    """
    Calculate labels based on the triple barrier method. Return a series of 
    event labels index by event start date, and return a series of event end 
    dates indexed by event start date.
    """

    # Remove event that don't have a proper chance to materialize
    time_delta_days = 90
    max_date = price_series.index.max()
    cutoff = max_date - pd.Timedelta(days=time_delta_days)
    event_index = event_index[event_index <= cutoff]

    # Use triple barrier method
    event_labels, event_spans = labels.compute_triple_barrier_labels(
        price_series,
        event_index,
        time_delta_days=time_delta_days,
        upper_z=1.8,
        lower_z=-1.8,
    )

    return event_labels, event_spans

# %% [markdown]
# ### 7.3 Computing Average Uniqueness

# %%
# See pypm.weights
import numpy as np
import pandas as pd
from scipy.stats import hmean

# %%
def calculate_uniqueness(event_spans: pd.Series, 
    price_index: pd.Series) -> pd.Series:
    """
    event_spans is a series with an index of start dates and values of end dates
    of a label.

    price_index is an index of underlying dates for the event

    Returns a series of uniqueness values that can be used as weights, indexed 
    as the event start dates. Weights may need to be standardized again before 
    training.
    """

    # Create a binary data frame 
    # value is 1 during event span and 0 otherwise
    columns = range(event_spans.shape[0])
    df = pd.DataFrame(0, index=price_index, columns=columns)

    for i, (event_start, event_end) in enumerate(event_spans.items()):
        df[i].loc[event_start:event_end] += 1

    # Compute concurrency over event span then calculate uniqueness
    uniquenesses = list()
    for i, (event_start, event_end) in enumerate(event_spans.items()):
        concurrency: pd.Series = df.loc[event_start:event_end].sum(axis=1)
        uniqueness = 1 / hmean(concurrency)
        uniquenesses.append(uniqueness)

    return pd.Series(uniquenesses, index=event_spans.index)

# %%
# See pypm.ml_model.weights
import numpy as np
import pandas as pd

from pypm.weights import calculate_uniqueness

# %%
def calculate_weights(event_spans: pd.Series, 
    price_index: pd.Series) -> pd.Series:
    return calculate_uniqueness(event_spans, price_index)

# %% [markdown]
# ### 7.4 Computing Features

# %%
import numpy as np
import pandas as pd

from pypm import indicators, filters, metrics

# %%
_calc_delta = filters.calculate_non_uniform_lagged_change
_calc_ma = indicators.calculate_simple_moving_average
_calc_log_return = metrics.calculate_log_return_series

# %%
def _calc_rolling_vol(series, n):
    return series.rolling(n).std() * np.sqrt(252 / n)

# %%
def calculate_features(price_series, revenue_series) -> pd.DataFrame:
    """
    Calculate any and all potentially useful features. Return as a dataframe.
    """

    log_revenue = np.log(revenue_series)
    log_prices = np.log(price_series)

    log_revenue_ma = _calc_ma(log_revenue, 10)
    log_prices_ma = _calc_ma(log_prices, 10)

    log_returns = _calc_log_return(price_series)

    features_by_name = dict()

    for i in [7, 30, 90, 180, 360]:

        rev_feature = _calc_delta(log_revenue_ma, i)
        price_feature = _calc_delta(log_prices_ma, i)
        vol_feature = _calc_rolling_vol(log_returns, i)

        features_by_name.update({
            f'{i}_day_revenue_delta': rev_feature,
            f'{i}_day_return': price_feature,
            f'{i}_day_vol': vol_feature,
        })

    features_df = pd.DataFrame(features_by_name)    
    return features_df

# %% [markdown]
# ### 7.5 Modeling and Cross Validation

# %%
# See pypm.ml_model.model
import numpy as np
import pandas as pd

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RepeatedKFold
from sklearn.base import clone

from joblib import Parallel, delayed

# %%
# Number of jobs to run in parallel
# Set to number of computer cores to use
N_JOBS = 10
N_SPLITS = 5
N_REPEATS = 4

# %%
def _fit_and_score(classifier, X, y, w, train_index, test_index, i) -> float:
    """
    The function used by joblib to split, train, and score cross validations
    """
    X_train = X.iloc[train_index]
    X_test = X.iloc[test_index]

    y_train = y.iloc[train_index]
    y_test = y.iloc[test_index]

    w_train = w.iloc[train_index]
    w_test = w.iloc[test_index]

    classifier.fit(X_train, y_train, w_train)
    score = classifier.score(X_test, y_test, w_test)

    print(f'Finished {i} ({100*score:.1f}%)')

    return score

# %%
def repeated_k_fold(classifier, X, y, w) -> np.ndarray:
    """
    Perform repeated k-fold cross validation on a classifier. Spread fitting 
    job over multiple computer cores.
    """
    n_jobs = N_JOBS

    n_splits = N_SPLITS
    n_repeats = N_REPEATS

    total_fits =  n_splits * n_repeats

    _k_fold = RepeatedKFold(n_splits=n_splits, n_repeats=n_repeats)

    print(f'Fitting {total_fits} models {n_jobs} at a time ...')
    print()

    parallel = Parallel(n_jobs=n_jobs)
    scores = parallel(
        delayed(_fit_and_score)(
            clone(classifier), X, y, w, train_index, test_index, i
        ) for i, (train_index, test_index) in enumerate(_k_fold.split(X))
    )

    return np.array(scores)

# %%
def calculate_model(df: pd.DataFrame) -> RandomForestClassifier:
    """
    Given a dataframe with a y column, weights column, and predictor columns 
    with arbitrary names, cross-validated and fit a classifier. Print 
    diagnostics.
    """
    classifier = RandomForestClassifier(n_estimators=100)

    # Separate data
    predictor_columns = [
        c for c in df.columns.values if not c in ('y', 'weights')
    ]
    X = df[predictor_columns]
    y = df['y']
    w = df['weights']

    # Fit cross validation
    scores = repeated_k_fold(classifier, X, y, w)

    # Get a full dataset fit for importance scores
    classifier.fit(X, y, w)

    # Compute diagnostics
    _imp = classifier.feature_importances_
    importance_series = pd.Series(_imp, index=predictor_columns)
    importance_series = importance_series.sort_values(ascending=False)

    # baseline accuracy is the best value achievable with a constant guess
    baseline = np.max(y.value_counts() / y.shape[0])

    # Compute a rough confidence interval for the improvement
    mean_score = scores.mean()
    std_score = scores.std()

    upper_bound = mean_score + 2 * std_score
    lower_bound = mean_score - 2 * std_score
    ibounds = (lower_bound - baseline, upper_bound - baseline)

    print('Feature importances')
    for col, imp in importance_series.items():
        print(f'{col:24} {imp:>.3f}')
    print()

    print('Cross validation scores')
    print(np.round(100 * scores, 1))
    print()

    print(f'Baseline accuracy {100*baseline:.1f}%')
    print(f'OOS accuracy {100*mean_score:.1f}% +/- {200 * scores.std():.1f}%')
    print(f'Improvement {100*(ibounds[0]):.1f} to {100*(ibounds[1]):.1f}%')
    print()

    return classifier

# %% [markdown]
# ### 7.6 Machine Learning Pipeline

# %%
# See fit_alternative_data_model.py
import os
import pandas as pd
import numpy as np
from typing import Dict

from joblib import dump

from pypm.ml_model.data_io import load_data
from pypm.ml_model.events import calculate_events
from pypm.ml_model.labels import calculate_labels
from pypm.ml_model.features import calculate_features
from pypm.ml_model.model import calculate_model
from pypm.ml_model.weights import calculate_weights

# %%
# SRC_DIR = os.path.dirname(os.path.abspath(__file__))
SRC_DIR = ""

# %%
# All the data we have to work with
symbols, eod_data, alt_data = load_data()

# The ML dataframe for each symbol, to be combined later
df_by_symbol: Dict[str, pd.DataFrame] = dict()

# Build ML dataframe for each symbol
for symbol in symbols:

    # Get revenue and price series
    revenue_series = alt_data[symbol].dropna()
    price_series = eod_data[symbol].dropna()
    price_index = price_series.index

    # Get events, labels, weights, and features
    event_index = calculate_events(revenue_series)
    event_labels, event_spans = calculate_labels(price_series, event_index)
    weights = calculate_weights(event_spans, price_index)
    features_df = calculate_features(price_series, revenue_series)

    # Subset features by event dates
    features_on_events = features_df.loc[event_index]

    # Convert labels and events to a data frame
    labels_df = pd.DataFrame(event_labels)
    labels_df.columns = ['y']

    # Converts weights to a data frame
    weights_df = pd.DataFrame(weights)
    weights_df.columns = ['weights']

    # Concatenate features to labels
    df = pd.concat([features_on_events, weights_df, labels_df], axis=1)
    df_by_symbol[symbol] = df

# Create final ML dataframe
df = pd.concat(df_by_symbol.values(), axis=0)
df.sort_index(inplace=True)
df.dropna(inplace=True)
print(df)

# Fit the model
classifier = calculate_model(df)

# Save the model
dump(classifier, os.path.join(SRC_DIR, 'ml_model.joblib'))
# Out:
#             7_day_revenue_delta  7_day_return  7_day_vol  \
# 2016-06-07            -0.000721      0.019520   0.096002
# 2016-06-08             0.029827      0.025005   0.113246
# 2016-06-08            -0.046427      0.013868   0.051878
# 2016-06-09             0.001558      0.032410   0.064574
# 2016-06-10             0.004933      0.011751   0.045105
# ...                         ...           ...        ...
# 2019-09-30            -0.031956     -0.008562   0.072845
# 2019-10-01            -0.074244     -0.018469   0.053665
# 2019-10-01             0.009513     -0.015659   0.094087
# 2019-10-02             0.003023      0.015749   0.043320
# 2019-10-02             0.012819     -0.008300   0.062938
#
#             30_day_revenue_delta  30_day_return  30_day_vol  \
# 2016-06-07              0.025643       0.033946    0.082937
# 2016-06-08              0.063757      -0.011531    0.056490
# 2016-06-08             -0.085587       0.021224    0.026436
# 2016-06-09              0.067627       0.004340    0.038006
# 2016-06-10              0.063808       0.000455    0.023268
# ...                          ...            ...         ...
# 2019-09-30              0.010339       0.043261    0.036866
# 2019-10-01              0.008044       0.092511    0.046558
# 2019-10-01              0.052674       0.106137    0.048047
# 2019-10-02              0.012013       0.027455    0.034185
# 2019-10-02              0.173430      -0.004390    0.039042
#
#             90_day_revenue_delta  90_day_return  90_day_vol  \
# 2016-06-07              0.036477       0.004284    0.038007
# 2016-06-08             -0.052050       0.173866    0.049978
# 2016-06-08             -0.137739       0.091066    0.017018
# 2016-06-09              0.017735      -0.008962    0.020438
# 2016-06-10              0.192992       0.114431    0.020221
# ...                          ...            ...         ...
# 2019-09-30              0.027737       0.170281    0.025694
# 2019-10-01             -0.017741      -0.004158    0.029420
# 2019-10-01              0.056772      -0.029641    0.025816
# 2019-10-02              0.059885       0.120898    0.021764
# 2019-10-02              0.788193       0.122567    0.026443
#
#             180_day_revenue_delta  180_day_return  180_day_vol  \
# 2016-06-07               0.077557       -0.216255     0.023150
# 2016-06-08              -0.298976       -0.119442     0.034954
# 2016-06-08              -0.062280        0.137259     0.014112
# 2016-06-09               0.042994       -0.071747     0.014624
# 2016-06-10               0.128870        0.115608     0.016394
# ...                           ...             ...          ...
# 2019-09-30               0.031291        0.194205     0.020289
# 2019-10-01               0.020292       -0.035468     0.022057
# 2019-10-01               0.092550       -0.023027     0.017416
# 2019-10-02               0.166203        0.149369     0.014530
# 2019-10-02               0.880612        0.252483     0.018372
#
#             360_day_revenue_delta  360_day_return  360_day_vol   weights    y
# 2016-06-07               0.059370       -0.300331     0.014388  1.000000 -1.0
# 2016-06-08              -0.458746       -0.396865     0.020529  0.246429 -1.0
# 2016-06-08              -0.149691        0.248088     0.011068  0.476744 -1.0
# 2016-06-09               0.044897        0.102727     0.010007  1.000000  0.0
# 2016-06-10               0.191210        0.148402     0.011307  0.500000  1.0
# ...                           ...             ...          ...       ...  ...
# 2019-09-30               0.321423       -0.161107     0.014908  0.416667  1.0
# 2019-10-01               0.042384       -0.233631     0.017987  1.000000  1.0
# 2019-10-01               0.140990       -0.087846     0.011337  0.801587  0.0
# 2019-10-02               0.180646        0.336547     0.010963  0.970588 -1.0
# 2019-10-02               0.990066        0.218280     0.014527  0.441156  0.0
#
# [1563 rows x 17 columns]
# Fitting 20 models 10 at a time ...
#
#
# Feature importances
# 30_day_return            0.097
# 7_day_return             0.094
# 30_day_vol               0.069
# 360_day_vol              0.068
# 90_day_return            0.066
# 360_day_revenue_delta    0.065
# 180_day_return           0.065
# 7_day_vol                0.065
# 180_day_revenue_delta    0.062
# 90_day_vol               0.060
# 360_day_return           0.060
# 180_day_vol              0.059
# 90_day_revenue_delta     0.058
# 30_day_revenue_delta     0.057
# 7_day_revenue_delta      0.057
#
# Cross validation scores
# [49.3 50.8 50.3 50.8 53.  54.3 52.5 52.9 51.2 45.6 54.9 55.1 47.2 52.7
#  52.6 53.5 47.2 53.  49.8 55.3]
#
# Baseline accuracy 42.2%
# OOS accuracy 51.6% +/- 5.3%
# Improvement 4.1 to 14.8%
# ['ml_model.joblib']

# %% [markdown]
# ### 7.7 Simulation with Machine Learning Model

# %%
import pandas as pd
import numpy as np

import os
from joblib import load

from pypm.ml_model.data_io import load_data
from pypm.ml_model.signals import calculate_signals

from pypm import metrics, simulation

# %%
# SRC_DIR = os.path.dirname(os.path.abspath(__file__))
SRC_DIR = ""

# %%
def simulate_portfolio():

    # All the data we have to work with
    symbols, eod_data, alt_data = load_data()

    # Load classifier from file
    classifier = load(os.path.join(SRC_DIR, 'ml_model.joblib'))

    # Generate signals from classifier
    print('Calculating signals ...')
    signal = calculate_signals(classifier, symbols, eod_data, alt_data)

    # Get rid of eod_data before valid signals
    first_signal_date = signal.first_valid_index()
    eod_data = eod_data[eod_data.index > first_signal_date]

    # Set the preference to increase by row, so new trades are preferred
    print('Calculating preference matrix ...')
    preference = pd.DataFrame(
        np.random.random(eod_data.shape), 
        columns=eod_data.columns, 
        index=eod_data.index,
    )

    # Run the simulator
    simulator = simulation.SimpleSimulator(
        initial_cash=10000,
        max_active_positions=10,
        percent_slippage=0.0005,
        trade_fee=1,
    )
    simulator.simulate(eod_data, signal, preference)

    # Print results
    simulator.portfolio_history.print_position_summaries()
    simulator.print_initial_parameters()
    simulator.portfolio_history.print_summary()
    simulator.portfolio_history.plot()
    simulator.portfolio_history.plot_benchmark_comparison()

# %%
simulate_portfolio()
# Out:
# Calculating signals ...
# Calculating preference matrix ...
# VBB       Trade summary
# Date:     Tue Jul 18, 2017 -> Tue Jul 25, 2017 [5 days]
# Price:    $281.41 -> $290.6 [3.3%]
# Value:    $997.07 -> $1029.63 [$32.56]
#
# HECP      Trade summary
# Date:     Tue Jul 11, 2017 -> Tue Jul 25, 2017 [10 days]
# Price:    $1137.62 -> $1211.49 [6.5%]
# Value:    $999.15 -> $1064.03 [$64.88]
#
# KGO       Trade summary
# Date:     Thu Jul 13, 2017 -> Wed Jul 26, 2017 [9 days]
# Price:    $95.9 -> $97.74 [1.9%]
# Value:    $998.57 -> $1017.75 [$19.18]
#
# EHH       Trade summary
# Date:     Fri Jul 07, 2017 -> Thu Jul 27, 2017 [14 days]
# Price:    $274.33 -> $300.76 [9.6%]
# Value:    $999.66 -> $1095.99 [$96.32]
#
# LJGB      Trade summary
# Date:     Mon Jul 17, 2017 -> Mon Jul 31, 2017 [10 days]
# Price:    $249.3 -> $259.16 [4.0%]
# Value:    $998.07 -> $1037.53 [$39.46]
#
# SLRR      Trade summary
# Date:     Thu Jul 27, 2017 -> Tue Aug 01, 2017 [3 days]
# Price:    $239.44 -> $243.41 [1.7%]
# Value:    $1094.44 -> $1112.59 [$18.15]
#
# UTQ       Trade summary
# Date:     Mon Jul 10, 2017 -> Tue Aug 01, 2017 [16 days]
# Price:    $240.97 -> $248.3 [3.0%]
# Value:    $999.35 -> $1029.75 [$30.4]
#
# FRCE      Trade summary
# Date:     Thu Jul 13, 2017 -> Wed Aug 02, 2017 [14 days]
# Price:    $154.42 -> $158.12 [2.4%]
# Value:    $998.9 -> $1022.86 [$23.95]
#
# PSWA      Trade summary
# Date:     Mon Jul 31, 2017 -> Mon Aug 07, 2017 [5 days]
# Price:    $444.75 -> $447.63 [0.6%]
# Value:    $1036.01 -> $1042.71 [$6.7]
#
# NZSR      Trade summary
# Date:     Mon Jul 10, 2017 -> Mon Aug 14, 2017 [25 days]
# Price:    $145.82 -> $150.22 [3.0%]
# Value:    $999.52 -> $1029.66 [$30.14]
#
# RVWV      Trade summary
# Date:     Thu Jul 06, 2017 -> Mon Aug 14, 2017 [27 days]
# Price:    $46.78 -> $54.35 [16.2%]
# Value:    $999.79 -> $1161.49 [$161.7]
#
# LMLK      Trade summary
# Date:     Tue Jul 25, 2017 -> Mon Aug 14, 2017 [14 days]
# Price:    $288.66 -> $300.0 [3.9%]
# Value:    $1062.5 -> $1104.23 [$41.72]
#
# NSLG      Trade summary
# Date:     Wed Jul 26, 2017 -> Tue Aug 15, 2017 [14 days]
# Price:    $622.72 -> $613.33 [-1.5%]
# Value:    $1016.24 -> $1000.92 [$-15.33]
#
# HECP      Trade summary
# Date:     Wed Aug 02, 2017 -> Wed Aug 16, 2017 [10 days]
# Price:    $1296.54 -> $1376.85 [6.2%]
# Value:    $1021.35 -> $1084.61 [$63.27]
#
# UTQ       Trade summary
# Date:     Tue Aug 15, 2017 -> Fri Aug 18, 2017 [3 days]
# Price:    $251.71 -> $253.11 [0.6%]
# Value:    $999.42 -> $1004.99 [$5.58]
#
# DVRL      Trade summary
# Date:     Mon Aug 14, 2017 -> Wed Aug 23, 2017 [7 days]
# Price:    $140.97 -> $136.98 [-2.8%]
# Value:    $1102.67 -> $1071.46 [$-31.21]
#
# ZZQB      Trade summary
# Date:     Wed Aug 16, 2017 -> Wed Aug 23, 2017 [5 days]
# Price:    $324.25 -> $327.13 [0.9%]
# Value:    $1083.07 -> $1092.68 [$9.61]
#
# BGN       Trade summary
# Date:     Mon Aug 14, 2017 -> Fri Aug 25, 2017 [9 days]
# Price:    $249.97 -> $242.79 [-2.9%]
# Value:    $1028.15 -> $998.59 [$-29.55]
#
# JXAN      Trade summary
# Date:     Tue Aug 01, 2017 -> Tue Aug 29, 2017 [20 days]
# Price:    $832.11 -> $831.78 [-0.0%]
# Value:    $1028.24 -> $1027.83 [$-0.4]
#
# FRCE      Trade summary
# Date:     Mon Aug 07, 2017 -> Wed Aug 30, 2017 [17 days]
# Price:    $156.8 -> $163.82 [4.5%]
# Value:    $1041.19 -> $1087.82 [$46.63]
#
# SIP       Trade summary
# Date:     Tue Aug 29, 2017 -> Thu Aug 31, 2017 [2 days]
# Price:    $289.76 -> $292.66 [1.0%]
# Value:    $1026.32 -> $1036.57 [$10.25]
#
# RALO      Trade summary
# Date:     Fri Aug 18, 2017 -> Fri Sep 01, 2017 [10 days]
# Price:    $263.6 -> $266.42 [1.1%]
# Value:    $1003.49 -> $1014.22 [$10.73]
#
# DLVY      Trade summary
# Date:     Wed Aug 30, 2017 -> Fri Sep 01, 2017 [2 days]
# Price:    $725.82 -> $741.82 [2.2%]
# Value:    $1086.27 -> $1110.21 [$23.94]
#
# IRX       Trade summary
# Date:     Thu Jul 06, 2017 -> Wed Sep 06, 2017 [43 days]
# Price:    $81.43 -> $84.71 [4.0%]
# Value:    $999.9 -> $1040.17 [$40.27]
#
# HESC      Trade summary
# Date:     Fri Sep 01, 2017 -> Mon Sep 11, 2017 [5 days]
# Price:    $90.91 -> $89.06 [-2.0%]
# Value:    $1012.71 -> $992.15 [$-20.56]
#
# AWU       Trade summary
# Date:     Wed Aug 23, 2017 -> Tue Sep 12, 2017 [13 days]
# Price:    $229.99 -> $231.7 [0.7%]
# Value:    $1069.93 -> $1077.86 [$7.93]
#
# PUO       Trade summary
# Date:     Wed Aug 23, 2017 -> Mon Sep 18, 2017 [17 days]
# Price:    $209.6 -> $225.35 [7.5%]
# Value:    $1091.14 -> $1173.1 [$81.96]
#
# FRCE      Trade summary
# Date:     Wed Sep 06, 2017 -> Tue Sep 19, 2017 [9 days]
# Price:    $164.1 -> $166.18 [1.3%]
# Value:    $1038.65 -> $1051.8 [$13.15]
#
# HECP      Trade summary
# Date:     Fri Aug 25, 2017 -> Wed Sep 20, 2017 [17 days]
# Price:    $1325.43 -> $1433.61 [8.2%]
# Value:    $997.09 -> $1078.47 [$81.38]
#
# EXY       Trade summary
# Date:     Fri Sep 01, 2017 -> Wed Sep 20, 2017 [12 days]
# Price:    $1793.13 -> $1941.19 [8.3%]
# Value:    $1108.66 -> $1200.2 [$91.55]
#
# UTQ       Trade summary
# Date:     Thu Aug 31, 2017 -> Fri Sep 22, 2017 [15 days]
# Price:    $260.0 -> $276.75 [6.4%]
# Value:    $1035.06 -> $1101.74 [$66.68]
#
# KTVL      Trade summary
# Date:     Mon Sep 11, 2017 -> Mon Sep 25, 2017 [10 days]
# Price:    $141.54 -> $151.11 [6.8%]
# Value:    $990.66 -> $1057.63 [$66.98]
#
# KGO       Trade summary
# Date:     Tue Aug 01, 2017 -> Wed Sep 27, 2017 [40 days]
# Price:    $100.64 -> $110.64 [9.9%]
# Value:    $1111.03 -> $1221.42 [$110.39]
#
# YPDA      Trade summary
# Date:     Tue Jul 25, 2017 -> Tue Oct 03, 2017 [49 days]
# Price:    $79.9 -> $90.51 [13.3%]
# Value:    $1028.12 -> $1164.64 [$136.53]
#
# TGXX      Trade summary
# Date:     Tue Sep 12, 2017 -> Tue Oct 03, 2017 [15 days]
# Price:    $543.54 -> $572.31 [5.3%]
# Value:    $1076.32 -> $1133.29 [$56.97]
#
# QEBK      Trade summary
# Date:     Mon Sep 18, 2017 -> Fri Oct 06, 2017 [14 days]
# Price:    $100.62 -> $99.96 [-0.7%]
# Value:    $1171.51 -> $1163.83 [$-7.69]
#
# BMG       Trade summary
# Date:     Wed Sep 20, 2017 -> Fri Oct 06, 2017 [12 days]
# Price:    $124.37 -> $135.94 [9.3%]
# Value:    $1076.94 -> $1177.1 [$100.17]
#
# EHH       Trade summary
# Date:     Mon Aug 14, 2017 -> Mon Oct 09, 2017 [39 days]
# Price:    $290.25 -> $341.86 [17.8%]
# Value:    $1159.91 -> $1366.18 [$206.27]
#
# HECP      Trade summary
# Date:     Fri Sep 22, 2017 -> Mon Oct 09, 2017 [11 days]
# Price:    $1435.33 -> $1436.2 [0.1%]
# Value:    $1100.19 -> $1100.86 [$0.67]
#
# PUO       Trade summary
# Date:     Fri Oct 06, 2017 -> Tue Oct 10, 2017 [2 days]
# Price:    $225.45 -> $226.27 [0.4%]
# Value:    $1162.24 -> $1166.46 [$4.21]
#
# XZFM      Trade summary
# Date:     Tue Oct 10, 2017 -> Wed Oct 11, 2017 [1 days]
# Price:    $409.93 -> $413.23 [0.8%]
# Value:    $1164.88 -> $1174.24 [$9.36]
#
# UTQ       Trade summary
# Date:     Wed Oct 11, 2017 -> Thu Oct 12, 2017 [1 days]
# Price:    $293.1 -> $296.29 [1.1%]
# Value:    $1172.65 -> $1185.43 [$12.78]
#
# HESC      Trade summary
# Date:     Mon Oct 09, 2017 -> Mon Oct 16, 2017 [5 days]
# Price:    $99.2 -> $98.78 [-0.4%]
# Value:    $1364.5 -> $1358.73 [$-5.77]
#
# RQG       Trade summary
# Date:     Wed Sep 27, 2017 -> Tue Oct 17, 2017 [14 days]
# Price:    $1008.57 -> $1042.18 [3.3%]
# Value:    $1219.81 -> $1260.46 [$40.64]
#
# SXQ       Trade summary
# Date:     Tue Oct 03, 2017 -> Wed Oct 18, 2017 [11 days]
# Price:    $375.27 -> $402.71 [7.3%]
# Value:    $1163.06 -> $1248.11 [$85.05]
#
# EXY       Trade summary
# Date:     Wed Oct 18, 2017 -> Fri Oct 20, 2017 [2 days]
# Price:    $2184.07 -> $2178.19 [-0.3%]
# Value:    $1246.49 -> $1243.13 [$-3.36]
#
# HECP      Trade summary
# Date:     Mon Oct 16, 2017 -> Tue Oct 24, 2017 [6 days]
# Price:    $1461.6 -> $1554.83 [6.4%]
# Value:    $1357.05 -> $1443.61 [$86.56]
#
# KEQ       Trade summary
# Date:     Fri Oct 20, 2017 -> Wed Oct 25, 2017 [3 days]
# Price:    $104.55 -> $106.38 [1.7%]
# Value:    $1241.51 -> $1263.21 [$21.7]
#
# WHMG      Trade summary
# Date:     Mon Sep 25, 2017 -> Wed Oct 25, 2017 [22 days]
# Price:    $164.5 -> $171.95 [4.5%]
# Value:    $1056.1 -> $1103.92 [$47.81]
#
# FJKV      Trade summary
# Date:     Tue Oct 17, 2017 -> Thu Oct 26, 2017 [7 days]
# Price:    $80.29 -> $80.19 [-0.1%]
# Value:    $1258.83 -> $1257.26 [$-1.57]
#
# IOV       Trade summary
# Date:     Tue Sep 19, 2017 -> Mon Oct 30, 2017 [29 days]
# Price:    $607.4 -> $683.47 [12.5%]
# Value:    $1050.27 -> $1181.8 [$131.53]
#
# PQCE      Trade summary
# Date:     Tue Oct 24, 2017 -> Mon Oct 30, 2017 [4 days]
# Price:    $1670.48 -> $1656.27 [-0.9%]
# Value:    $1441.89 -> $1429.62 [$-12.27]
#
# YPDA      Trade summary
# Date:     Mon Oct 30, 2017 -> Fri Nov 03, 2017 [4 days]
# Price:    $89.44 -> $97.89 [9.4%]
# Value:    $1427.9 -> $1562.72 [$134.82]
#
# RVWV      Trade summary
# Date:     Mon Oct 30, 2017 -> Mon Nov 06, 2017 [5 days]
# Price:    $56.11 -> $58.9 [5.0%]
# Value:    $1180.21 -> $1238.94 [$58.73]
#
# RLZA      Trade summary
# Date:     Wed Sep 20, 2017 -> Tue Nov 07, 2017 [34 days]
# Price:    $99.23 -> $111.35 [12.2%]
# Value:    $1198.6 -> $1345.01 [$146.4]
#
# NSLG      Trade summary
# Date:     Mon Oct 09, 2017 -> Wed Nov 08, 2017 [22 days]
# Price:    $660.08 -> $698.63 [5.8%]
# Value:    $1099.31 -> $1163.51 [$64.2]
#
# RALO      Trade summary
# Date:     Thu Oct 26, 2017 -> Fri Nov 10, 2017 [11 days]
# Price:    $253.67 -> $268.2 [5.7%]
# Value:    $1255.63 -> $1327.57 [$71.94]
#
# XWR       Trade summary
# Date:     Wed Oct 25, 2017 -> Mon Nov 13, 2017 [13 days]
# Price:    $183.38 -> $162.74 [-11.3%]
# Value:    $1102.37 -> $978.28 [$-124.08]
#
# HESC      Trade summary
# Date:     Wed Nov 08, 2017 -> Mon Nov 13, 2017 [3 days]
# Price:    $97.35 -> $96.78 [-0.6%]
# Value:    $1161.93 -> $1155.14 [$-6.79]
#
# SIP       Trade summary
# Date:     Tue Nov 07, 2017 -> Mon Nov 13, 2017 [4 days]
# Price:    $335.85 -> $326.84 [-2.7%]
# Value:    $1343.33 -> $1307.3 [$-36.03]
#
# QEBK      Trade summary
# Date:     Mon Nov 06, 2017 -> Tue Nov 21, 2017 [11 days]
# Price:    $104.52 -> $107.21 [2.6%]
# Value:    $1237.32 -> $1269.14 [$31.82]
#
# NZSR      Trade summary
# Date:     Fri Nov 03, 2017 -> Wed Nov 22, 2017 [13 days]
# Price:    $189.52 -> $194.01 [2.4%]
# Value:    $1560.94 -> $1597.88 [$36.94]
#
# RLZA      Trade summary
# Date:     Mon Nov 13, 2017 -> Fri Nov 24, 2017 [8 days]
# Price:    $106.61 -> $107.83 [1.1%]
# Value:    $976.79 -> $987.94 [$11.15]
#
# KTVL      Trade summary
# Date:     Fri Nov 10, 2017 -> Mon Nov 27, 2017 [10 days]
# Price:    $154.78 -> $156.53 [1.1%]
# Value:    $1325.9 -> $1340.92 [$15.01]
#
# CHWK      Trade summary
# Date:     Mon Nov 13, 2017 -> Tue Nov 28, 2017 [10 days]
# Price:    $257.34 -> $252.2 [-2.0%]
# Value:    $1305.65 -> $1279.58 [$-26.07]
#
# RQG       Trade summary
# Date:     Wed Nov 22, 2017 -> Wed Nov 29, 2017 [4 days]
# Price:    $1096.65 -> $1088.51 [-0.7%]
# Value:    $1596.08 -> $1584.24 [$-11.84]
#
# ZZQB      Trade summary
# Date:     Mon Nov 13, 2017 -> Fri Dec 01, 2017 [13 days]
# Price:    $361.24 -> $352.27 [-2.5%]
# Value:    $1153.56 -> $1124.92 [$-28.65]
#
# KGO       Trade summary
# Date:     Thu Oct 12, 2017 -> Mon Dec 04, 2017 [36 days]
# Price:    $110.11 -> $114.06 [3.6%]
# Value:    $1183.84 -> $1226.36 [$42.52]
#
# UZS       Trade summary
# Date:     Wed Oct 25, 2017 -> Tue Dec 05, 2017 [28 days]
# Price:    $324.7 -> $349.05 [7.5%]
# Value:    $1261.58 -> $1356.18 [$94.6]
#
# OZMT      Trade summary
# Date:     Tue Oct 03, 2017 -> Tue Dec 05, 2017 [44 days]
# Price:    $414.79 -> $456.52 [10.1%]
# Value:    $1131.72 -> $1245.58 [$113.86]
#
# KGO       Trade summary
# Date:     Tue Dec 05, 2017 -> Wed Dec 06, 2017 [1 days]
# Price:    $114.58 -> $112.61 [-1.7%]
# Value:    $1354.5 -> $1331.24 [$-23.26]
#
# FRCE      Trade summary
# Date:     Fri Oct 06, 2017 -> Fri Dec 08, 2017 [44 days]
# Price:    $160.85 -> $187.14 [16.3%]
# Value:    $1175.51 -> $1367.64 [$192.13]
#
# WOXI      Trade summary
# Date:     Tue Nov 21, 2017 -> Mon Dec 11, 2017 [13 days]
# Price:    $129.05 -> $129.93 [0.7%]
# Value:    $1267.5 -> $1276.1 [$8.6]
#
# ZWH       Trade summary
# Date:     Tue Nov 28, 2017 -> Tue Dec 12, 2017 [10 days]
# Price:    $412.43 -> $416.2 [0.9%]
# Value:    $1277.94 -> $1289.63 [$11.69]
#
# MTZB      Trade summary
# Date:     Tue Dec 05, 2017 -> Tue Dec 12, 2017 [5 days]
# Price:    $90.5 -> $89.98 [-0.6%]
# Value:    $1243.96 -> $1236.88 [$-7.08]
#
# ZZQB      Trade summary
# Date:     Tue Dec 12, 2017 -> Thu Dec 14, 2017 [2 days]
# Price:    $354.24 -> $353.35 [-0.3%]
# Value:    $1235.26 -> $1232.17 [$-3.09]
#
# SIP       Trade summary
# Date:     Fri Dec 08, 2017 -> Wed Dec 20, 2017 [8 days]
# Price:    $343.94 -> $355.3 [3.3%]
# Value:    $1365.96 -> $1411.06 [$45.11]
#
# NDQC      Trade summary
# Date:     Mon Dec 04, 2017 -> Wed Dec 20, 2017 [12 days]
# Price:    $1374.46 -> $1404.71 [2.2%]
# Value:    $1224.75 -> $1251.7 [$26.96]
#
# NZSR      Trade summary
# Date:     Fri Dec 01, 2017 -> Wed Dec 20, 2017 [13 days]
# Price:    $197.17 -> $215.17 [9.1%]
# Value:    $1123.35 -> $1225.91 [$102.56]
#
# ZXGV      Trade summary
# Date:     Wed Dec 20, 2017 -> Thu Dec 21, 2017 [1 days]
# Price:    $234.13 -> $235.92 [0.8%]
# Value:    $1224.3 -> $1233.68 [$9.38]
#
# NSLG      Trade summary
# Date:     Thu Dec 14, 2017 -> Wed Dec 27, 2017 [8 days]
# Price:    $717.05 -> $731.61 [2.0%]
# Value:    $1230.55 -> $1255.54 [$24.99]
#
# JWDV      Trade summary
# Date:     Wed Dec 27, 2017 -> Tue Jan 02, 2018 [3 days]
# Price:    $465.33 -> $482.5 [3.7%]
# Value:    $1253.91 -> $1300.17 [$46.26]
#
# DLVY      Trade summary
# Date:     Mon Nov 27, 2017 -> Tue Jan 02, 2018 [24 days]
# Price:    $799.77 -> $843.62 [5.5%]
# Value:    $1339.25 -> $1412.68 [$73.43]
#
# ZEA       Trade summary
# Date:     Fri Nov 24, 2017 -> Wed Jan 03, 2018 [26 days]
# Price:    $70.25 -> $84.73 [20.6%]
# Value:    $986.45 -> $1189.86 [$203.41]
#
# IOV       Trade summary
# Date:     Wed Nov 29, 2017 -> Thu Jan 04, 2018 [24 days]
# Price:    $696.56 -> $759.56 [9.0%]
# Value:    $1582.45 -> $1725.58 [$143.13]
#
# PSWA      Trade summary
# Date:     Tue Jan 02, 2018 -> Fri Jan 05, 2018 [3 days]
# Price:    $465.13 -> $490.68 [5.5%]
# Value:    $1410.97 -> $1488.47 [$77.5]
#
# JXAN      Trade summary
# Date:     Tue Dec 12, 2017 -> Tue Jan 16, 2018 [22 days]
# Price:    $878.02 -> $1010.48 [15.1%]
# Value:    $1287.99 -> $1482.3 [$194.31]
#
# OWKQ      Trade summary
# Date:     Wed Dec 20, 2017 -> Wed Jan 24, 2018 [22 days]
# Price:    $692.51 -> $765.12 [10.5%]
# Value:    $1409.36 -> $1557.14 [$147.78]
#
# RLZA      Trade summary
# Date:     Wed Dec 06, 2017 -> Fri Feb 02, 2018 [39 days]
# Price:    $110.76 -> $125.46 [13.3%]
# Value:    $1329.58 -> $1506.1 [$176.52]
#
# IRX       Trade summary
# Date:     Mon Dec 11, 2017 -> Thu Feb 08, 2018 [40 days]
# Price:    $85.43 -> $92.78 [8.6%]
# Value:    $1274.46 -> $1384.07 [$109.61]
#
# NDQC      Trade summary
# Date:     Fri Jan 05, 2018 -> Thu Feb 08, 2018 [23 days]
# Price:    $1452.7 -> $1420.32 [-2.2%]
# Value:    $1486.72 -> $1453.59 [$-33.13]
#
# HESC      Trade summary
# Date:     Thu Feb 08, 2018 -> Tue Feb 20, 2018 [7 days]
# Price:    $115.57 -> $122.87 [6.3%]
# Value:    $1451.86 -> $1543.6 [$91.74]
#
# ZOE       Trade summary
# Date:     Wed Dec 20, 2017 -> Thu Mar 01, 2018 [47 days]
# Price:    $82.37 -> $85.0 [3.2%]
# Value:    $1250.08 -> $1289.97 [$39.9]
#
# CUU       Trade summary
# Date:     Tue Jan 16, 2018 -> Fri Mar 02, 2018 [32 days]
# Price:    $239.01 -> $226.8 [-5.1%]
# Value:    $1480.56 -> $1404.93 [$-75.63]
#
# ZXGV      Trade summary
# Date:     Thu Feb 08, 2018 -> Fri Mar 09, 2018 [20 days]
# Price:    $228.65 -> $253.07 [10.7%]
# Value:    $1382.38 -> $1529.99 [$147.61]
#
# VLOZ      Trade summary
# Date:     Wed Jan 03, 2018 -> Wed Mar 14, 2018 [48 days]
# Price:    $301.76 -> $279.63 [-7.3%]
# Value:    $1188.26 -> $1101.12 [$-87.15]
#
# KGO       Trade summary
# Date:     Tue Feb 20, 2018 -> Tue Mar 20, 2018 [20 days]
# Price:    $118.98 -> $117.18 [-1.5%]
# Value:    $1541.83 -> $1518.51 [$-23.32]
#
# JXAN      Trade summary
# Date:     Wed Jan 24, 2018 -> Thu Mar 22, 2018 [40 days]
# Price:    $1059.72 -> $1249.88 [17.9%]
# Value:    $1555.36 -> $1834.46 [$279.1]
#
# UAIG      Trade summary
# Date:     Wed Mar 14, 2018 -> Thu Mar 22, 2018 [6 days]
# Price:    $402.0 -> $425.44 [5.8%]
# Value:    $1099.57 -> $1163.68 [$64.11]
#
# KEQ       Trade summary
# Date:     Tue Mar 20, 2018 -> Fri Mar 23, 2018 [3 days]
# Price:    $111.58 -> $106.56 [-4.5%]
# Value:    $1516.75 -> $1448.57 [$-68.18]
#
# AWU       Trade summary
# Date:     Thu Jan 04, 2018 -> Tue Mar 27, 2018 [56 days]
# Price:    $313.3 -> $346.08 [10.5%]
# Value:    $1723.71 -> $1904.08 [$180.37]
#
# FRCE      Trade summary
# Date:     Thu Dec 21, 2017 -> Tue Apr 03, 2018 [68 days]
# Price:    $187.94 -> $234.49 [24.8%]
# Value:    $1232.06 -> $1537.19 [$305.13]
#
# FSVO      Trade summary
# Date:     Thu Mar 22, 2018 -> Thu Apr 05, 2018 [9 days]
# Price:    $305.76 -> $311.16 [1.8%]
# Value:    $1162.1 -> $1182.61 [$20.51]
#
# XZFM      Trade summary
# Date:     Fri Mar 09, 2018 -> Thu Apr 05, 2018 [18 days]
# Price:    $495.21 -> $493.94 [-0.3%]
# Value:    $1528.22 -> $1524.31 [$-3.91]
#
# KSR       Trade summary
# Date:     Tue Mar 27, 2018 -> Fri Apr 06, 2018 [7 days]
# Price:    $326.4 -> $332.03 [1.7%]
# Value:    $1902.13 -> $1934.92 [$32.79]
#
# PQCE      Trade summary
# Date:     Fri Apr 06, 2018 -> Wed Apr 11, 2018 [3 days]
# Price:    $1802.5 -> $1846.47 [2.4%]
# Value:    $1932.95 -> $1980.11 [$47.15]
#
# YPDA      Trade summary
# Date:     Fri Mar 23, 2018 -> Thu Apr 12, 2018 [13 days]
# Price:    $78.42 -> $76.88 [-2.0%]
# Value:    $1446.84 -> $1418.44 [$-28.4]
#
# RQG       Trade summary
# Date:     Thu Apr 12, 2018 -> Fri Apr 13, 2018 [1 days]
# Price:    $1211.18 -> $1212.02 [0.1%]
# Value:    $1416.73 -> $1417.72 [$0.99]
#
# HECP      Trade summary
# Date:     Thu Mar 01, 2018 -> Fri Apr 13, 2018 [30 days]
# Price:    $1939.72 -> $2157.12 [11.2%]
# Value:    $1288.33 -> $1432.72 [$144.39]
#
# FRCE      Trade summary
# Date:     Fri Apr 13, 2018 -> Mon Apr 16, 2018 [1 days]
# Price:    $238.99 -> $240.45 [0.6%]
# Value:    $1431.01 -> $1439.75 [$8.75]
#
# VBB       Trade summary
# Date:     Fri Feb 02, 2018 -> Fri Apr 20, 2018 [53 days]
# Price:    $350.32 -> $392.37 [12.0%]
# Value:    $1504.35 -> $1684.95 [$180.6]
#
# KGO       Trade summary
# Date:     Thu Apr 05, 2018 -> Mon Apr 23, 2018 [12 days]
# Price:    $129.69 -> $141.74 [9.3%]
# Value:    $1181.02 -> $1290.7 [$109.69]
#
# IEZI      Trade summary
# Date:     Wed Apr 11, 2018 -> Tue Apr 24, 2018 [9 days]
# Price:    $416.67 -> $414.26 [-0.6%]
# Value:    $1978.12 -> $1966.68 [$-11.43]
#
# JXAN      Trade summary
# Date:     Mon Apr 16, 2018 -> Tue Apr 24, 2018 [6 days]
# Price:    $1238.47 -> $1166.37 [-5.8%]
# Value:    $1438.03 -> $1354.31 [$-83.72]
#
# ZOE       Trade summary
# Date:     Tue Apr 24, 2018 -> Thu Apr 26, 2018 [2 days]
# Price:    $84.32 -> $86.52 [2.6%]
# Value:    $1964.7 -> $2015.91 [$51.21]
#
# DLVY      Trade summary
# Date:     Tue Apr 24, 2018 -> Fri Apr 27, 2018 [3 days]
# Price:    $754.18 -> $761.57 [1.0%]
# Value:    $1352.64 -> $1365.9 [$13.26]
#
# QEBK      Trade summary
# Date:     Tue Jan 02, 2018 -> Fri Apr 27, 2018 [80 days]
# Price:    $112.09 -> $109.92 [-1.9%]
# Value:    $1298.52 -> $1273.43 [$-25.09]
#
# FJKV      Trade summary
# Date:     Fri Mar 02, 2018 -> Fri May 04, 2018 [44 days]
# Price:    $80.64 -> $87.64 [8.7%]
# Value:    $1403.22 -> $1525.03 [$121.8]
#
# XWR       Trade summary
# Date:     Tue Apr 03, 2018 -> Mon May 07, 2018 [24 days]
# Price:    $205.52 -> $217.83 [6.0%]
# Value:    $1535.42 -> $1627.37 [$91.95]
#
# KSR       Trade summary
# Date:     Mon Apr 23, 2018 -> Mon May 07, 2018 [10 days]
# Price:    $326.93 -> $349.08 [6.8%]
# Value:    $1289.06 -> $1376.38 [$87.32]
#
# BMG       Trade summary
# Date:     Fri Apr 27, 2018 -> Mon May 07, 2018 [6 days]
# Price:    $126.02 -> $125.09 [-0.7%]
# Value:    $1271.79 -> $1262.38 [$-9.42]
#
# SIP       Trade summary
# Date:     Fri Apr 27, 2018 -> Tue May 08, 2018 [7 days]
# Price:    $315.92 -> $329.93 [4.4%]
# Value:    $1364.21 -> $1424.72 [$60.51]
#
# XYCJ      Trade summary
# Date:     Thu Mar 22, 2018 -> Thu May 10, 2018 [34 days]
# Price:    $208.69 -> $225.61 [8.1%]
# Value:    $1832.54 -> $1981.08 [$148.54]
#
# JWDV      Trade summary
# Date:     Fri Apr 20, 2018 -> Tue May 15, 2018 [17 days]
# Price:    $397.93 -> $416.79 [4.7%]
# Value:    $1683.1 -> $1762.88 [$79.78]
#
# CHWK      Trade summary
# Date:     Thu Apr 26, 2018 -> Mon May 21, 2018 [17 days]
# Price:    $214.37 -> $248.4 [15.9%]
# Value:    $2013.9 -> $2333.63 [$319.73]
#
# UZS       Trade summary
# Date:     Thu Apr 05, 2018 -> Tue May 22, 2018 [33 days]
# Price:    $402.06 -> $417.16 [3.8%]
# Value:    $1522.55 -> $1579.72 [$57.18]
#
# TRE       Trade summary
# Date:     Mon May 21, 2018 -> Thu May 24, 2018 [3 days]
# Price:    $302.76 -> $301.61 [-0.4%]
# Value:    $2331.46 -> $2322.6 [$-8.87]
#
# FJKV      Trade summary
# Date:     Tue May 22, 2018 -> Thu May 24, 2018 [2 days]
# Price:    $86.37 -> $87.01 [0.7%]
# Value:    $1577.93 -> $1589.57 [$11.63]
#
# FSVO      Trade summary
# Date:     Fri Apr 13, 2018 -> Thu May 24, 2018 [29 days]
# Price:    $318.92 -> $330.63 [3.7%]
# Value:    $1416.01 -> $1468.01 [$52.0]
#
# XWR       Trade summary
# Date:     Thu May 24, 2018 -> Fri May 25, 2018 [1 days]
# Price:    $206.28 -> $206.29 [0.0%]
# Value:    $2320.43 -> $2320.51 [$0.08]
#
# ZWH       Trade summary
# Date:     Fri May 25, 2018 -> Wed May 30, 2018 [2 days]
# Price:    $371.05 -> $367.72 [-0.9%]
# Value:    $2318.35 -> $2297.57 [$-20.78]
#
# OZMT      Trade summary
# Date:     Fri May 04, 2018 -> Thu Jun 07, 2018 [23 days]
# Price:    $385.87 -> $374.89 [-2.8%]
# Value:    $1523.26 -> $1479.91 [$-43.36]
#
# DLVY      Trade summary
# Date:     Tue May 15, 2018 -> Fri Jun 08, 2018 [17 days]
# Price:    $752.19 -> $790.95 [5.2%]
# Value:    $1761.0 -> $1851.75 [$90.75]
#
# IRX       Trade summary
# Date:     Thu May 10, 2018 -> Tue Jun 12, 2018 [22 days]
# Price:    $109.84 -> $126.25 [14.9%]
# Value:    $1979.09 -> $2274.66 [$295.57]
#
# LJGB      Trade summary
# Date:     Tue May 08, 2018 -> Tue Jun 12, 2018 [24 days]
# Price:    $233.21 -> $240.33 [3.1%]
# Value:    $1423.01 -> $1466.48 [$43.47]
#
# DLVY      Trade summary
# Date:     Tue Jun 12, 2018 -> Fri Jun 15, 2018 [3 days]
# Price:    $797.72 -> $801.14 [0.4%]
# Value:    $1464.74 -> $1471.03 [$6.28]
#
# OKK       Trade summary
# Date:     Wed May 30, 2018 -> Fri Jun 15, 2018 [12 days]
# Price:    $41.66 -> $40.04 [-3.9%]
# Value:    $2295.42 -> $2206.12 [$-89.3]
#
# KSR       Trade summary
# Date:     Fri Jun 15, 2018 -> Wed Jun 20, 2018 [3 days]
# Price:    $345.22 -> $348.4 [0.9%]
# Value:    $2204.02 -> $2224.3 [$20.29]
#
# FSVO      Trade summary
# Date:     Tue Jun 12, 2018 -> Thu Jun 21, 2018 [7 days]
# Price:    $341.0 -> $342.08 [0.3%]
# Value:    $2272.53 -> $2279.72 [$7.19]
#
# XWR       Trade summary
# Date:     Fri Jun 08, 2018 -> Fri Jun 22, 2018 [10 days]
# Price:    $214.39 -> $263.19 [22.8%]
# Value:    $1849.83 -> $2270.92 [$421.09]
#
# JXAN      Trade summary
# Date:     Thu Jun 07, 2018 -> Fri Jun 22, 2018 [11 days]
# Price:    $1258.08 -> $1251.9 [-0.5%]
# Value:    $1478.17 -> $1470.91 [$-7.26]
#
# ZEA       Trade summary
# Date:     Fri Jun 22, 2018 -> Fri Jun 29, 2018 [5 days]
# Price:    $84.4 -> $84.68 [0.3%]
# Value:    $1469.17 -> $1474.01 [$4.84]
#
# RALO      Trade summary
# Date:     Thu May 24, 2018 -> Fri Jun 29, 2018 [25 days]
# Price:    $254.72 -> $260.32 [2.2%]
# Value:    $1587.77 -> $1622.7 [$34.92]
#
# EZVY      Trade summary
# Date:     Thu May 24, 2018 -> Fri Jun 29, 2018 [25 days]
# Price:    $644.64 -> $689.4 [6.9%]
# Value:    $1466.27 -> $1568.08 [$101.8]
#
# WFS       Trade summary
# Date:     Thu Jun 21, 2018 -> Mon Jul 02, 2018 [7 days]
# Price:    $316.36 -> $308.64 [-2.4%]
# Value:    $2277.58 -> $2222.02 [$-55.57]
#
# XZFM      Trade summary
# Date:     Mon May 07, 2018 -> Thu Jul 05, 2018 [41 days]
# Price:    $514.47 -> $555.89 [8.1%]
# Value:    $1260.75 -> $1362.26 [$101.51]
#
# OCG       Trade summary
# Date:     Fri Jun 29, 2018 -> Thu Jul 05, 2018 [3 days]
# Price:    $409.14 -> $413.03 [0.9%]
# Value:    $1566.29 -> $1581.17 [$14.87]
#
# RLZA      Trade summary
# Date:     Mon Jul 02, 2018 -> Mon Jul 09, 2018 [4 days]
# Price:    $125.02 -> $126.46 [1.1%]
# Value:    $2219.9 -> $2245.43 [$25.52]
#
# PUO       Trade summary
# Date:     Fri Jun 29, 2018 -> Thu Jul 12, 2018 [8 days]
# Price:    $227.89 -> $227.96 [0.0%]
# Value:    $1620.89 -> $1621.36 [$0.47]
#
# HECP      Trade summary
# Date:     Mon May 07, 2018 -> Thu Jul 12, 2018 [46 days]
# Price:    $2172.0 -> $2770.1 [27.5%]
# Value:    $1625.56 -> $2073.19 [$447.63]
#
# MEF       Trade summary
# Date:     Thu Jul 12, 2018 -> Tue Jul 17, 2018 [3 days]
# Price:    $488.85 -> $495.07 [1.3%]
# Value:    $2071.15 -> $2097.48 [$26.33]
#
# OKK       Trade summary
# Date:     Fri Jun 22, 2018 -> Wed Jul 18, 2018 [17 days]
# Price:    $41.57 -> $42.96 [3.3%]
# Value:    $2268.78 -> $2344.6 [$75.82]
#
# VBB       Trade summary
# Date:     Mon May 07, 2018 -> Wed Jul 18, 2018 [50 days]
# Price:    $409.89 -> $474.3 [15.7%]
# Value:    $1374.69 -> $1590.69 [$216.0]
#
# FJZC      Trade summary
# Date:     Fri Jun 15, 2018 -> Thu Jul 19, 2018 [23 days]
# Price:    $335.99 -> $358.69 [6.8%]
# Value:    $1469.29 -> $1568.57 [$99.28]
#
# IEZI      Trade summary
# Date:     Wed Jul 18, 2018 -> Fri Jul 20, 2018 [2 days]
# Price:    $491.52 -> $492.14 [0.1%]
# Value:    $2342.43 -> $2345.4 [$2.98]
#
# JWDV      Trade summary
# Date:     Fri Jun 29, 2018 -> Tue Jul 24, 2018 [16 days]
# Price:    $432.21 -> $550.01 [27.3%]
# Value:    $1472.27 -> $1873.56 [$401.29]
#
# KEQ       Trade summary
# Date:     Wed Jun 20, 2018 -> Tue Jul 24, 2018 [23 days]
# Price:    $116.09 -> $123.7 [6.6%]
# Value:    $2222.19 -> $2367.9 [$145.71]
#
# DLVY      Trade summary
# Date:     Thu Jul 05, 2018 -> Tue Jul 24, 2018 [13 days]
# Price:    $807.8 -> $841.78 [4.2%]
# Value:    $1360.58 -> $1417.8 [$57.23]
#
# IRX       Trade summary
# Date:     Fri Jul 20, 2018 -> Wed Jul 25, 2018 [3 days]
# Price:    $126.43 -> $125.89 [-0.4%]
# Value:    $2343.23 -> $2333.16 [$-10.07]
#
# JXAN      Trade summary
# Date:     Thu Jul 05, 2018 -> Thu Jul 26, 2018 [15 days]
# Price:    $1278.71 -> $1382.14 [8.1%]
# Value:    $1579.38 -> $1707.13 [$127.75]
#
# DVRL      Trade summary
# Date:     Wed Jul 18, 2018 -> Thu Jul 26, 2018 [6 days]
# Price:    $122.98 -> $128.23 [4.3%]
# Value:    $1588.9 -> $1656.71 [$67.81]
#
# VHE       Trade summary
# Date:     Thu Jul 26, 2018 -> Wed Aug 01, 2018 [4 days]
# Price:    $353.81 -> $347.79 [-1.7%]
# Value:    $1705.28 -> $1676.28 [$-29.0]
#
# VDHJ      Trade summary
# Date:     Thu Jul 26, 2018 -> Fri Aug 03, 2018 [6 days]
# Price:    $175.44 -> $177.78 [1.3%]
# Value:    $1654.88 -> $1676.97 [$22.09]
#
# ZZQB      Trade summary
# Date:     Tue Jul 24, 2018 -> Mon Aug 06, 2018 [9 days]
# Price:    $284.51 -> $295.69 [3.9%]
# Value:    $2365.72 -> $2458.66 [$92.94]
#
# OKK       Trade summary
# Date:     Wed Aug 01, 2018 -> Tue Aug 07, 2018 [4 days]
# Price:    $41.17 -> $41.12 [-0.1%]
# Value:    $1674.44 -> $1672.38 [$-2.06]
#
# KGO       Trade summary
# Date:     Mon Aug 06, 2018 -> Tue Aug 07, 2018 [1 days]
# Price:    $159.87 -> $162.68 [1.8%]
# Value:    $2456.43 -> $2499.61 [$43.18]
#
# FRCE      Trade summary
# Date:     Tue Aug 07, 2018 -> Wed Aug 08, 2018 [1 days]
# Price:    $286.52 -> $288.25 [0.6%]
# Value:    $2497.36 -> $2512.41 [$15.05]
#
# ZWH       Trade summary
# Date:     Tue Jul 17, 2018 -> Thu Aug 09, 2018 [17 days]
# Price:    $381.56 -> $385.64 [1.1%]
# Value:    $2095.44 -> $2117.84 [$22.4]
#
# KEQ       Trade summary
# Date:     Tue Aug 07, 2018 -> Fri Aug 10, 2018 [3 days]
# Price:    $126.11 -> $125.62 [-0.4%]
# Value:    $1670.55 -> $1664.01 [$-6.53]
#
# XAU       Trade summary
# Date:     Thu Jul 19, 2018 -> Mon Aug 13, 2018 [17 days]
# Price:    $139.85 -> $150.42 [7.6%]
# Value:    $1566.78 -> $1685.2 [$118.42]
#
# BGN       Trade summary
# Date:     Mon Jul 09, 2018 -> Tue Aug 14, 2018 [26 days]
# Price:    $236.39 -> $247.76 [4.8%]
# Value:    $2243.31 -> $2351.22 [$107.92]
#
# ZOE       Trade summary
# Date:     Tue Jul 24, 2018 -> Tue Aug 21, 2018 [20 days]
# Price:    $93.71 -> $97.6 [4.2%]
# Value:    $1416.09 -> $1474.93 [$58.83]
#
# SIP       Trade summary
# Date:     Wed Jul 25, 2018 -> Thu Aug 23, 2018 [21 days]
# Price:    $311.96 -> $322.58 [3.4%]
# Value:    $2331.0 -> $2410.38 [$79.39]
#
# DLVY      Trade summary
# Date:     Tue Aug 14, 2018 -> Fri Aug 24, 2018 [8 days]
# Price:    $855.86 -> $883.4 [3.2%]
# Value:    $2349.05 -> $2424.64 [$75.59]
#
# XWR       Trade summary
# Date:     Tue Jul 24, 2018 -> Fri Aug 31, 2018 [28 days]
# Price:    $242.89 -> $262.7 [8.2%]
# Value:    $1871.62 -> $2024.26 [$152.64]
#
# PDX       Trade summary
# Date:     Wed Aug 08, 2018 -> Fri Sep 07, 2018 [21 days]
# Price:    $338.12 -> $342.23 [1.2%]
# Value:    $2510.16 -> $2540.68 [$30.52]
#
# VBB       Trade summary
# Date:     Thu Aug 09, 2018 -> Mon Sep 10, 2018 [21 days]
# Price:    $460.54 -> $493.3 [7.1%]
# Value:    $2115.78 -> $2266.28 [$150.5]
#
# RLZA      Trade summary
# Date:     Fri Aug 03, 2018 -> Fri Sep 14, 2018 [29 days]
# Price:    $126.74 -> $135.02 [6.5%]
# Value:    $1675.13 -> $1784.52 [$109.39]
#
# KGO       Trade summary
# Date:     Mon Sep 10, 2018 -> Fri Sep 28, 2018 [14 days]
# Price:    $156.79 -> $168.36 [7.4%]
# Value:    $2264.15 -> $2431.25 [$167.1]
#
# NZSR      Trade summary
# Date:     Fri Aug 31, 2018 -> Wed Oct 03, 2018 [22 days]
# Price:    $196.95 -> $221.13 [12.3%]
# Value:    $2022.25 -> $2270.54 [$248.29]
#
# AXC       Trade summary
# Date:     Thu Jul 12, 2018 -> Tue Oct 09, 2018 [62 days]
# Price:    $188.44 -> $214.27 [13.7%]
# Value:    $1619.55 -> $1841.5 [$221.96]
#
# PQCE      Trade summary
# Date:     Fri Aug 24, 2018 -> Wed Oct 17, 2018 [37 days]
# Price:    $2153.46 -> $2625.34 [21.9%]
# Value:    $2422.43 -> $2953.26 [$530.82]
#
# FJZC      Trade summary
# Date:     Wed Oct 03, 2018 -> Thu Oct 25, 2018 [16 days]
# Price:    $366.2 -> $383.23 [4.6%]
# Value:    $2349.22 -> $2458.45 [$109.23]
#
# OBAK      Trade summary
# Date:     Thu Oct 25, 2018 -> Fri Oct 26, 2018 [1 days]
# Price:    $61.23 -> $58.45 [-4.5%]
# Value:    $2456.22 -> $2344.68 [$-111.54]
#
# EZVY      Trade summary
# Date:     Fri Oct 26, 2018 -> Mon Oct 29, 2018 [1 days]
# Price:    $712.66 -> $728.61 [2.2%]
# Value:    $2342.51 -> $2394.95 [$52.44]
#
# XZFM      Trade summary
# Date:     Fri Aug 10, 2018 -> Fri Nov 16, 2018 [69 days]
# Price:    $576.22 -> $608.33 [5.6%]
# Value:    $1662.18 -> $1754.81 [$92.63]
#
# BMG       Trade summary
# Date:     Thu Oct 04, 2018 -> Mon Nov 26, 2018 [36 days]
# Price:    $136.94 -> $144.01 [5.2%]
# Value:    $2348.22 -> $2469.49 [$121.26]
#
# KEQ       Trade summary
# Date:     Mon Oct 29, 2018 -> Wed Dec 12, 2018 [30 days]
# Price:    $127.13 -> $136.71 [7.5%]
# Value:    $2392.75 -> $2572.99 [$180.24]
#
# DVRL      Trade summary
# Date:     Tue Dec 04, 2018 -> Mon Dec 17, 2018 [8 days]
# Price:    $116.18 -> $109.92 [-5.4%]
# Value:    $2109.59 -> $1995.96 [$-113.64]
#
# RALO      Trade summary
# Date:     Fri Sep 07, 2018 -> Wed Dec 19, 2018 [71 days]
# Price:    $281.19 -> $304.29 [8.2%]
# Value:    $2538.41 -> $2746.93 [$208.53]
#
# JXAN      Trade summary
# Date:     Tue Aug 21, 2018 -> Thu Dec 20, 2018 [84 days]
# Price:    $1302.79 -> $1311.89 [0.7%]
# Value:    $1473.19 -> $1483.48 [$10.29]
#
# WFS       Trade summary
# Date:     Tue Nov 27, 2018 -> Fri Dec 21, 2018 [17 days]
# Price:    $360.75 -> $357.25 [-1.0%]
# Value:    $2110.59 -> $2090.12 [$-20.48]
#
# XYCJ      Trade summary
# Date:     Mon Aug 13, 2018 -> Fri Dec 21, 2018 [91 days]
# Price:    $227.9 -> $212.91 [-6.6%]
# Value:    $1683.36 -> $1572.61 [$-110.75]
#
# ZOE       Trade summary
# Date:     Wed Oct 17, 2018 -> Wed Dec 26, 2018 [47 days]
# Price:    $108.15 -> $107.85 [-0.3%]
# Value:    $2950.78 -> $2942.48 [$-8.3]
#
# RVWV      Trade summary
# Date:     Wed Dec 19, 2018 -> Fri Dec 28, 2018 [6 days]
# Price:    $44.55 -> $45.46 [2.0%]
# Value:    $2744.56 -> $2800.48 [$55.92]
#
# RQG       Trade summary
# Date:     Fri Dec 28, 2018 -> Mon Dec 31, 2018 [1 days]
# Price:    $1284.13 -> $1285.16 [0.1%]
# Value:    $2798.08 -> $2800.32 [$2.24]
#
# SXQ       Trade summary
# Date:     Thu Aug 23, 2018 -> Mon Dec 31, 2018 [88 days]
# Price:    $393.8 -> $448.8 [14.0%]
# Value:    $2408.18 -> $2744.54 [$336.36]
#
# CUU       Trade summary
# Date:     Fri Dec 14, 2018 -> Tue Jan 15, 2019 [20 days]
# Price:    $181.37 -> $197.15 [8.7%]
# Value:    $2570.7 -> $2794.35 [$223.65]
#
# RVWV      Trade summary
# Date:     Tue Jan 15, 2019 -> Wed Jan 16, 2019 [1 days]
# Price:    $49.99 -> $51.21 [2.4%]
# Value:    $2791.96 -> $2859.81 [$67.85]
#
# LMLK      Trade summary
# Date:     Thu Dec 20, 2018 -> Thu Jan 17, 2019 [18 days]
# Price:    $371.09 -> $392.5 [5.8%]
# Value:    $1481.74 -> $1567.24 [$85.51]
#
# MHNG      Trade summary
# Date:     Tue Oct 09, 2018 -> Fri Jan 18, 2019 [69 days]
# Price:    $235.12 -> $239.24 [1.8%]
# Value:    $1839.58 -> $1871.84 [$32.25]
#
# FJKV      Trade summary
# Date:     Wed Sep 19, 2018 -> Fri Jan 18, 2019 [83 days]
# Price:    $95.66 -> $101.88 [6.5%]
# Value:    $1782.63 -> $1898.59 [$115.95]
#
# DVRL      Trade summary
# Date:     Fri Jan 18, 2019 -> Wed Jan 23, 2019 [2 days]
# Price:    $124.52 -> $121.61 [-2.3%]
# Value:    $1896.64 -> $1852.28 [$-44.36]
#
# XSOQ      Trade summary
# Date:     Thu Jan 17, 2019 -> Thu Jan 24, 2019 [4 days]
# Price:    $173.92 -> $175.36 [0.8%]
# Value:    $1565.46 -> $1578.45 [$12.99]
#
# IRX       Trade summary
# Date:     Mon Dec 17, 2018 -> Tue Feb 05, 2019 [33 days]
# Price:    $128.39 -> $159.88 [24.5%]
# Value:    $1993.96 -> $2482.93 [$488.97]
#
# CUU       Trade summary
# Date:     Thu Jan 24, 2019 -> Tue Feb 05, 2019 [8 days]
# Price:    $202.16 -> $207.47 [2.6%]
# Value:    $1576.66 -> $1618.07 [$41.4]
#
# JMS       Trade summary
# Date:     Wed Dec 26, 2018 -> Mon Feb 11, 2019 [31 days]
# Price:    $478.09 -> $587.12 [22.8%]
# Value:    $2940.01 -> $3610.5 [$670.49]
#
# KEQ       Trade summary
# Date:     Tue Feb 05, 2019 -> Fri Mar 01, 2019 [17 days]
# Price:    $128.5 -> $136.67 [6.4%]
# Value:    $2480.69 -> $2638.33 [$157.64]
#
# OZMT      Trade summary
# Date:     Fri Dec 21, 2018 -> Mon Mar 04, 2019 [47 days]
# Price:    $353.04 -> $480.24 [36.0%]
# Value:    $2088.07 -> $2840.43 [$752.36]
#
# PUO       Trade summary
# Date:     Wed Jan 16, 2019 -> Mon Mar 04, 2019 [31 days]
# Price:    $216.28 -> $244.76 [13.2%]
# Value:    $2857.38 -> $3233.67 [$376.29]
#
# EZVY      Trade summary
# Date:     Fri Dec 21, 2018 -> Wed Mar 06, 2019 [49 days]
# Price:    $751.16 -> $829.26 [10.4%]
# Value:    $1570.83 -> $1734.16 [$163.33]
#
# SLRR      Trade summary
# Date:     Fri Jan 18, 2019 -> Wed Mar 06, 2019 [31 days]
# Price:    $304.5 -> $344.19 [13.0%]
# Value:    $1869.9 -> $2113.62 [$243.72]
#
# CHWK      Trade summary
# Date:     Tue Feb 05, 2019 -> Mon Mar 11, 2019 [23 days]
# Price:    $203.63 -> $219.4 [7.7%]
# Value:    $1616.26 -> $1741.41 [$125.15]
#
# ZZQB      Trade summary
# Date:     Mon Mar 04, 2019 -> Wed Mar 13, 2019 [7 days]
# Price:    $323.3 -> $328.39 [1.6%]
# Value:    $3231.05 -> $3281.91 [$50.85]
#
# RQG       Trade summary
# Date:     Fri Mar 01, 2019 -> Fri Mar 15, 2019 [10 days]
# Price:    $1458.79 -> $1531.87 [5.0%]
# Value:    $2636.01 -> $2768.07 [$132.06]
#
# VBB       Trade summary
# Date:     Mon Dec 31, 2018 -> Fri Mar 15, 2019 [51 days]
# Price:    $419.32 -> $545.84 [30.2%]
# Value:    $2797.92 -> $3642.13 [$844.21]
#
# CUU       Trade summary
# Date:     Wed Mar 06, 2019 -> Wed Mar 20, 2019 [10 days]
# Price:    $214.67 -> $215.89 [0.6%]
# Value:    $1732.29 -> $1742.16 [$9.87]
#
# YPDA      Trade summary
# Date:     Mon Feb 11, 2019 -> Thu Mar 21, 2019 [27 days]
# Price:    $66.46 -> $83.6 [25.8%]
# Value:    $3607.69 -> $4537.9 [$930.2]
#
# KUAQ      Trade summary
# Date:     Fri Mar 15, 2019 -> Mon Mar 25, 2019 [6 days]
# Price:    $536.47 -> $544.01 [1.4%]
# Value:    $2765.68 -> $2804.56 [$38.88]
#
# BGN       Trade summary
# Date:     Wed Mar 13, 2019 -> Tue Mar 26, 2019 [9 days]
# Price:    $290.33 -> $283.4 [-2.4%]
# Value:    $3279.27 -> $3201.05 [$-78.22]
#
# TQKA      Trade summary
# Date:     Mon Mar 11, 2019 -> Tue Apr 09, 2019 [21 days]
# Price:    $336.32 -> $357.3 [6.2%]
# Value:    $1739.54 -> $1848.07 [$108.52]
#
# OZI       Trade summary
# Date:     Wed Mar 06, 2019 -> Wed Apr 10, 2019 [25 days]
# Price:    $385.13 -> $416.68 [8.2%]
# Value:    $2111.56 -> $2284.53 [$172.97]
#
# VDHJ      Trade summary
# Date:     Wed Mar 20, 2019 -> Mon Apr 15, 2019 [18 days]
# Price:    $181.16 -> $189.59 [4.7%]
# Value:    $1740.29 -> $1821.26 [$80.98]
#
# KEQ       Trade summary
# Date:     Mon Apr 15, 2019 -> Mon May 06, 2019 [14 days]
# Price:    $144.03 -> $158.51 [10.1%]
# Value:    $1819.35 -> $2002.23 [$182.88]
#
# LMLK      Trade summary
# Date:     Mon Mar 04, 2019 -> Thu May 09, 2019 [47 days]
# Price:    $416.99 -> $459.17 [10.1%]
# Value:    $2838.01 -> $3125.09 [$287.09]
#
# FRCE      Trade summary
# Date:     Thu Mar 21, 2019 -> Fri May 10, 2019 [35 days]
# Price:    $282.7 -> $288.29 [2.0%]
# Value:    $4534.63 -> $4624.27 [$89.65]
#
# RQG       Trade summary
# Date:     Thu May 09, 2019 -> Mon May 13, 2019 [2 days]
# Price:    $1575.97 -> $1555.8 [-1.3%]
# Value:    $3122.53 -> $3082.57 [$-39.96]
#
# TGXX      Trade summary
# Date:     Mon Mar 25, 2019 -> Wed May 15, 2019 [36 days]
# Price:    $461.82 -> $491.75 [6.5%]
# Value:    $2802.16 -> $2983.76 [$181.6]
#
# WNE       Trade summary
# Date:     Wed Jan 23, 2019 -> Thu May 16, 2019 [79 days]
# Price:    $349.98 -> $440.14 [25.8%]
# Value:    $1850.35 -> $2327.0 [$476.65]
#
# SEBI      Trade summary
# Date:     Thu May 16, 2019 -> Fri May 17, 2019 [1 days]
# Price:    $891.14 -> $891.36 [0.0%]
# Value:    $2324.84 -> $2325.42 [$0.59]
#
# AXC       Trade summary
# Date:     Tue Apr 09, 2019 -> Thu May 23, 2019 [31 days]
# Price:    $188.1 -> $207.14 [10.1%]
# Value:    $1846.14 -> $2032.97 [$186.83]
#
# JXAN      Trade summary
# Date:     Mon Dec 31, 2018 -> Fri May 31, 2019 [104 days]
# Price:    $1382.85 -> $1999.99 [44.6%]
# Value:    $2742.17 -> $3965.94 [$1223.77]
#
# NEGH      Trade summary
# Date:     Fri May 10, 2019 -> Mon Jun 03, 2019 [15 days]
# Price:    $192.75 -> $195.94 [1.7%]
# Value:    $4620.96 -> $4697.53 [$76.57]
#
# SLRR      Trade summary
# Date:     Wed Apr 10, 2019 -> Thu Jun 06, 2019 [39 days]
# Price:    $348.86 -> $414.51 [18.8%]
# Value:    $2282.38 -> $2711.86 [$429.48]
#
# XJJI      Trade summary
# Date:     Mon May 13, 2019 -> Thu Jun 06, 2019 [17 days]
# Price:    $141.36 -> $149.14 [5.5%]
# Value:    $3080.03 -> $3249.53 [$169.5]
#
# CHWK      Trade summary
# Date:     Fri Mar 15, 2019 -> Tue Jun 18, 2019 [65 days]
# Price:    $214.41 -> $244.47 [14.0%]
# Value:    $3639.31 -> $4149.59 [$510.28]
#
# CUU       Trade summary
# Date:     Thu Jun 06, 2019 -> Mon Jun 24, 2019 [12 days]
# Price:    $246.92 -> $249.73 [1.1%]
# Value:    $2709.5 -> $2740.3 [$30.8]
#
# KSR       Trade summary
# Date:     Fri May 31, 2019 -> Tue Jun 25, 2019 [17 days]
# Price:    $368.38 -> $373.24 [1.3%]
# Value:    $3962.96 -> $4015.2 [$52.24]
#
# WFS       Trade summary
# Date:     Mon Jun 03, 2019 -> Wed Jun 26, 2019 [17 days]
# Price:    $407.16 -> $439.74 [8.0%]
# Value:    $4694.18 -> $5069.75 [$375.57]
#
# UTQ       Trade summary
# Date:     Mon Jun 24, 2019 -> Wed Jun 26, 2019 [2 days]
# Price:    $296.29 -> $298.23 [0.7%]
# Value:    $2737.93 -> $2755.87 [$17.94]
#
# UAIG      Trade summary
# Date:     Mon May 06, 2019 -> Tue Jul 09, 2019 [44 days]
# Price:    $841.3 -> $924.32 [9.9%]
# Value:    $2000.23 -> $2197.62 [$197.38]
#
# XWR       Trade summary
# Date:     Tue Mar 26, 2019 -> Thu Jul 11, 2019 [74 days]
# Price:    $258.71 -> $293.07 [13.3%]
# Value:    $3198.45 -> $3623.25 [$424.8]
#
# FJKV      Trade summary
# Date:     Wed Jun 26, 2019 -> Tue Jul 16, 2019 [13 days]
# Price:    $110.51 -> $113.51 [2.7%]
# Value:    $5066.22 -> $5203.97 [$137.76]
#
# FRCE      Trade summary
# Date:     Wed May 15, 2019 -> Tue Jul 16, 2019 [42 days]
# Price:    $287.39 -> $330.91 [15.1%]
# Value:    $2981.27 -> $3432.68 [$451.42]
#
# VLOZ      Trade summary
# Date:     Fri May 17, 2019 -> Fri Jul 19, 2019 [43 days]
# Price:    $218.82 -> $237.69 [8.6%]
# Value:    $2323.26 -> $2523.61 [$200.35]
#
# ZGL       Trade summary
# Date:     Tue Jul 16, 2019 -> Fri Jul 26, 2019 [8 days]
# Price:    $62.28 -> $62.2 [-0.1%]
# Value:    $5200.37 -> $5193.6 [$-6.77]
#
# WNE       Trade summary
# Date:     Thu May 23, 2019 -> Fri Jul 26, 2019 [44 days]
# Price:    $424.14 -> $459.37 [8.3%]
# Value:    $2030.95 -> $2199.64 [$168.69]
#
# PDX       Trade summary
# Date:     Tue Jul 09, 2019 -> Mon Jul 29, 2019 [14 days]
# Price:    $429.26 -> $437.68 [2.0%]
# Value:    $2195.52 -> $2238.56 [$43.04]
#
# IRX       Trade summary
# Date:     Fri Jul 26, 2019 -> Thu Aug 01, 2019 [4 days]
# Price:    $189.5 -> $186.59 [-1.5%]
# Value:    $5190.0 -> $5110.18 [$-79.83]
#
# SLRR      Trade summary
# Date:     Wed Jun 26, 2019 -> Tue Aug 06, 2019 [28 days]
# Price:    $402.43 -> $439.02 [9.1%]
# Value:    $2753.5 -> $3003.84 [$250.35]
#
# EZVY      Trade summary
# Date:     Tue Jul 16, 2019 -> Thu Aug 08, 2019 [17 days]
# Price:    $923.31 -> $956.87 [3.6%]
# Value:    $3429.97 -> $3554.63 [$124.67]
#
# XYCJ      Trade summary
# Date:     Mon Jul 29, 2019 -> Fri Aug 09, 2019 [9 days]
# Price:    $242.81 -> $245.55 [1.1%]
# Value:    $2236.44 -> $2261.66 [$25.22]
#
# PSWA      Trade summary
# Date:     Thu Jun 06, 2019 -> Mon Aug 12, 2019 [46 days]
# Price:    $706.5 -> $704.68 [-0.3%]
# Value:    $3246.91 -> $3238.53 [$-8.38]
#
# IEZI      Trade summary
# Date:     Tue Jun 25, 2019 -> Wed Aug 14, 2019 [35 days]
# Price:    $385.59 -> $378.18 [-1.9%]
# Value:    $4012.19 -> $3935.06 [$-77.13]
#
# VLOZ      Trade summary
# Date:     Fri Aug 09, 2019 -> Thu Aug 15, 2019 [4 days]
# Price:    $254.46 -> $252.43 [-0.8%]
# Value:    $2259.53 -> $2241.53 [$-18.0]
#
# DVRL      Trade summary
# Date:     Wed Aug 14, 2019 -> Fri Aug 16, 2019 [2 days]
# Price:    $128.85 -> $130.67 [1.4%]
# Value:    $3932.09 -> $3987.49 [$55.4]
#
# JWDV      Trade summary
# Date:     Tue Aug 06, 2019 -> Fri Aug 30, 2019 [18 days]
# Price:    $342.63 -> $319.33 [-6.8%]
# Value:    $3001.34 -> $2797.23 [$-204.11]
#
# IOV       Trade summary
# Date:     Mon Aug 12, 2019 -> Tue Sep 03, 2019 [15 days]
# Price:    $425.25 -> $429.02 [0.9%]
# Value:    $3235.91 -> $3264.58 [$28.67]
#
# EXY       Trade summary
# Date:     Tue Sep 03, 2019 -> Fri Sep 06, 2019 [3 days]
# Price:    $1602.72 -> $1715.61 [7.0%]
# Value:    $3261.95 -> $3491.7 [$229.76]
#
# SGVQ      Trade summary
# Date:     Thu Aug 08, 2019 -> Tue Sep 24, 2019 [32 days]
# Price:    $92.21 -> $98.16 [6.5%]
# Value:    $3551.86 -> $3781.21 [$229.35]
#
# PDX       Trade summary
# Date:     Thu Aug 15, 2019 -> Fri Sep 27, 2019 [30 days]
# Price:    $449.75 -> $477.93 [6.3%]
# Value:    $2239.41 -> $2379.7 [$140.29]
#
# VLOZ      Trade summary
# Date:     Fri Sep 06, 2019 -> Tue Oct 01, 2019 [17 days]
# Price:    $268.6 -> $268.68 [0.0%]
# Value:    $3488.96 -> $3489.94 [$0.98]
#
# IEZI      Trade summary
# Date:     Tue Sep 24, 2019 -> Mon Oct 07, 2019 [9 days]
# Price:    $387.73 -> $384.56 [-0.8%]
# Value:    $3778.31 -> $3747.39 [$-30.93]
#
# BGN       Trade summary
# Date:     Fri Sep 27, 2019 -> Thu Oct 10, 2019 [9 days]
# Price:    $321.11 -> $315.07 [-1.9%]
# Value:    $2377.51 -> $2332.79 [$-44.72]
#
# NDQC      Trade summary
# Date:     Fri Jul 19, 2019 -> Thu Oct 10, 2019 [58 days]
# Price:    $1488.76 -> $1546.84 [3.9%]
# Value:    $2521.35 -> $2619.71 [$98.36]
#
# TGXX      Trade summary
# Date:     Thu Oct 10, 2019 -> Fri Oct 11, 2019 [1 days]
# Price:    $494.98 -> $516.63 [4.4%]
# Value:    $2330.62 -> $2432.57 [$101.95]
#
# CHWK      Trade summary
# Date:     Thu Jul 11, 2019 -> Mon Oct 14, 2019 [66 days]
# Price:    $253.84 -> $282.82 [11.4%]
# Value:    $3620.44 -> $4033.82 [$413.38]
#
# DVRL      Trade summary
# Date:     Thu Oct 10, 2019 -> Tue Oct 15, 2019 [3 days]
# Price:    $139.28 -> $145.48 [4.5%]
# Value:    $2617.4 -> $2733.92 [$116.52]
#
# UAIG      Trade summary
# Date:     Fri Oct 11, 2019 -> Wed Oct 16, 2019 [3 days]
# Price:    $981.64 -> $964.77 [-1.7%]
# Value:    $2430.36 -> $2388.59 [$-41.77]
#
# UZS       Trade summary
# Date:     Fri Aug 30, 2019 -> Mon Oct 28, 2019 [40 days]
# Price:    $439.44 -> $468.02 [6.5%]
# Value:    $2794.83 -> $2976.6 [$181.77]
#
# FSVO      Trade summary
# Date:     Mon Oct 07, 2019 -> Wed Nov 06, 2019 [22 days]
# Price:    $358.65 -> $364.88 [1.7%]
# Value:    $3744.51 -> $3809.57 [$65.05]
#
# SLRR      Trade summary
# Date:     Wed Nov 06, 2019 -> Wed Nov 13, 2019 [5 days]
# Price:    $421.11 -> $427.57 [1.5%]
# Value:    $3806.66 -> $3865.05 [$58.39]
#
# FRCE      Trade summary
# Date:     Wed Oct 16, 2019 -> Mon Nov 18, 2019 [23 days]
# Price:    $282.42 -> $309.47 [9.6%]
# Value:    $2386.39 -> $2614.95 [$228.56]
#
# MEF       Trade summary
# Date:     Mon Oct 14, 2019 -> Tue Nov 19, 2019 [26 days]
# Price:    $567.48 -> $598.32 [5.4%]
# Value:    $4030.8 -> $4249.83 [$219.03]
#
# PUO       Trade summary
# Date:     Mon Oct 28, 2019 -> Tue Nov 19, 2019 [16 days]
# Price:    $284.73 -> $310.28 [9.0%]
# Value:    $2974.11 -> $3240.97 [$266.85]
#
# XZFM      Trade summary
# Date:     Mon Nov 18, 2019 -> Wed Nov 20, 2019 [2 days]
# Price:    $792.09 -> $786.3 [-0.7%]
# Value:    $2612.64 -> $2593.56 [$-19.08]
#
# SLRR      Trade summary
# Date:     Wed Nov 20, 2019 -> Tue Nov 26, 2019 [4 days]
# Price:    $441.29 -> $432.15 [-2.1%]
# Value:    $2591.26 -> $2537.59 [$-53.67]
#
# RQG       Trade summary
# Date:     Tue Nov 26, 2019 -> Wed Nov 27, 2019 [1 days]
# Price:    $1876.31 -> $1892.77 [0.9%]
# Value:    $2535.32 -> $2557.57 [$22.24]
#
# UFT       Trade summary
# Date:     Tue Oct 01, 2019 -> Mon Dec 02, 2019 [43 days]
# Price:    $274.64 -> $320.72 [16.8%]
# Value:    $3487.2 -> $4072.33 [$585.13]
#
# SLRR      Trade summary
# Date:     Wed Nov 27, 2019 -> Fri Dec 06, 2019 [6 days]
# Price:    $434.43 -> $413.86 [-4.7%]
# Value:    $2555.29 -> $2434.31 [$-120.98]
#
# ZOE       Trade summary
# Date:     Thu Aug 01, 2019 -> Thu Dec 12, 2019 [93 days]
# Price:    $125.59 -> $130.47 [3.9%]
# Value:    $5106.62 -> $5304.93 [$198.31]
#
# TQKA      Trade summary
# Date:     Thu Dec 12, 2019 -> Fri Dec 13, 2019 [1 days]
# Price:    $386.83 -> $384.85 [-0.5%]
# Value:    $5301.28 -> $5274.1 [$-27.18]
#
# AWU       Trade summary
# Date:     Tue Dec 10, 2019 -> Mon Dec 16, 2019 [4 days]
# Price:    $313.06 -> $334.0 [6.7%]
# Value:    $2432.09 -> $2594.8 [$162.71]
#
# VDHJ      Trade summary
# Date:     Mon Dec 02, 2019 -> Tue Dec 17, 2019 [11 days]
# Price:    $194.21 -> $200.29 [3.1%]
# Value:    $4069.3 -> $4196.75 [$127.46]
#
# NDQC      Trade summary
# Date:     Tue Oct 15, 2019 -> Tue Dec 17, 2019 [44 days]
# Price:    $1605.35 -> $1581.38 [-1.5%]
# Value:    $2731.55 -> $2690.76 [$-40.79]
#
# UZS       Trade summary
# Date:     Tue Nov 19, 2019 -> Thu Dec 19, 2019 [21 days]
# Price:    $477.39 -> $520.34 [9.0%]
# Value:    $3238.35 -> $3529.71 [$291.36]
#
# NEGH      Trade summary
# Date:     Tue Jun 18, 2019 -> Thu Dec 19, 2019 [129 days]
# Price:    $205.15 -> $244.69 [19.3%]
# Value:    $4146.51 -> $4945.64 [$799.13]
#
# LMLK      Trade summary
# Date:     Thu Dec 19, 2019 -> Mon Dec 23, 2019 [2 days]
# Price:    $537.9 -> $544.91 [1.3%]
# Value:    $3526.94 -> $3572.91 [$45.97]
#
# ZZQB      Trade summary
# Date:     Tue Dec 17, 2019 -> Tue Dec 24, 2019 [5 days]
# Price:    $380.06 -> $376.29 [-1.0%]
# Value:    $4193.66 -> $4152.06 [$-41.6]
#
# OBAK      Trade summary
# Date:     Tue Dec 17, 2019 -> Tue Dec 24, 2019 [5 days]
# Price:    $73.8 -> $75.63 [2.5%]
# Value:    $2688.42 -> $2755.2 [$66.78]
#
# CHWK      Trade summary
# Date:     Fri Nov 15, 2019 -> Tue Dec 24, 2019 [26 days]
# Price:    $277.15 -> $266.89 [-3.7%]
# Value:    $3862.12 -> $3719.17 [$-142.95]
#
# ZXGV      Trade summary
# Date:     Tue Nov 19, 2019 -> Mon Dec 30, 2019 [27 days]
# Price:    $202.68 -> $211.08 [4.1%]
# Value:    $4246.71 -> $4422.68 [$175.98]
#
# WHMG      Trade summary
# Date:     Fri Jul 26, 2019 -> Tue Dec 31, 2019 [109 days]
# Price:    $168.36 -> $186.84 [11.0%]
# Value:    $2197.54 -> $2438.69 [$241.15]
#
# MTZB      Trade summary
# Date:     Fri Aug 16, 2019 -> Tue Dec 31, 2019 [94 days]
# Price:    $95.08 -> $125.93 [32.4%]
# Value:    $3984.5 -> $5277.46 [$1292.96]
#
# OZMT      Trade summary
# Date:     Fri Dec 13, 2019 -> Tue Dec 31, 2019 [11 days]
# Price:    $485.98 -> $504.34 [3.8%]
# Value:    $5270.46 -> $5469.54 [$199.08]
#
# FJKV      Trade summary
# Date:     Mon Dec 16, 2019 -> Tue Dec 31, 2019 [10 days]
# Price:    $126.93 -> $125.91 [-0.8%]
# Value:    $2592.5 -> $2571.6 [$-20.9]
#
# VDHJ      Trade summary
# Date:     Thu Dec 19, 2019 -> Tue Dec 31, 2019 [7 days]
# Price:    $199.27 -> $200.0 [0.4%]
# Value:    $4942.17 -> $4960.28 [$18.12]
#
# HXX       Trade summary
# Date:     Mon Dec 23, 2019 -> Tue Dec 31, 2019 [5 days]
# Price:    $296.69 -> $289.25 [-2.5%]
# Value:    $3570.13 -> $3480.62 [$-89.51]
#
# JXAN      Trade summary
# Date:     Tue Dec 24, 2019 -> Tue Dec 31, 2019 [4 days]
# Price:    $2101.47 -> $2085.67 [-0.8%]
# Value:    $4148.98 -> $4117.79 [$-31.19]
#
# KSR       Trade summary
# Date:     Tue Dec 24, 2019 -> Tue Dec 31, 2019 [4 days]
# Price:    $370.59 -> $380.29 [2.6%]
# Value:    $2752.82 -> $2824.91 [$72.09]
#
# OZI       Trade summary
# Date:     Tue Dec 24, 2019 -> Tue Dec 31, 2019 [4 days]
# Price:    $394.9 -> $390.2 [-1.2%]
# Value:    $3716.31 -> $3672.1 [$-44.21]
#
# SLRR      Trade summary
# Date:     Mon Dec 30, 2019 -> Tue Dec 31, 2019 [1 days]
# Price:    $437.3 -> $432.88 [-1.0%]
# Value:    $4419.47 -> $4374.82 [$-44.66]
#
# Initial Cash: $10000
# Maximum Number of Assets: 10
#
# Equity: $39168.22
# Percent Return: 291.68%
# S&P 500 Return: 33.80%
#
# Number of trades: 302
# Average active trades: 9.91
#
# CAGR: 73.08%
# S&P 500 CAGR: 12.43%
# Excess CAGR: 60.65%
#
# Annualized Volatility: 13.75%
# Sharpe Ratio: 5.32
# Jensen's Alpha: 0.001805
#
# Dollar Max Drawdown: $1947.34
# Percent Max Drawdown: 8.48%
# Log Max Drawdown Ratio: 1.28
